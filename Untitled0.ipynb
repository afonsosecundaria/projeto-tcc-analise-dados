# %% [markdown]
# <a href="https://colab.research.google.com/github/afonsosecundaria/projeto-tcc-analise-dados/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
tabela_cvt = pd.read_excel('arquivos/Estatísticas_CVT_2018.xlsx')
tabela_cvt.head()
# Out:
#   ESTATÍSTICAS CVT-ESPACIAL - 2018  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                             NOME         NaN         NaN         NaN
# 1       GABRIEL LUIS REIS DE SOUZA         NaN         NaN         NaN
# 2          LARISSA OLIVEIRA MENDES         NaN         NaN         NaN
# 3       ALANA CRISTINA PESSOA LIMA         NaN         NaN         NaN
# 4             CAIO LUCAS DA SILVA          NaN         NaN         NaN
#
#    Unnamed: 4  Unnamed: 5          Unnamed: 6  Unnamed: 7 Unnamed: 8  \
# 0         NaN         NaN  DATA DE NASCIMENTO         NaN    CONTATO
# 1         NaN         NaN                 NaN         NaN        NaN
# 2         NaN         NaN                 NaN         NaN        NaN
# 3         NaN         NaN                 NaN         NaN        NaN
# 4         NaN         NaN                 NaN         NaN        NaN
#
#    Unnamed: 9  ...  Unnamed: 16  Unnamed: 17  Unnamed: 18 Unnamed: 19  \
# ...

# %%
# 1 passo: tratar os dados da tabela

# excluir colunas inúteis

tabela_cvt = tabela_cvt.drop(columns=['Unnamed: 1',	'Unnamed: 2',	'Unnamed: 3',	'Unnamed: 4',	'Unnamed: 5',
                                      'Unnamed: 7','Unnamed: 9','Unnamed: 10',	'Unnamed: 11',	'Unnamed: 12','Unnamed: 14',
                                      'Unnamed: 15', 'Unnamed: 17', 'Unnamed: 18',	'Unnamed: 19',
                                      'Unnamed: 20',	'Unnamed: 21','Unnamed: 23',	'Unnamed: 24'], errors='ignore')
tabela_cvt.head()
# Out:
#   ESTATÍSTICAS CVT-ESPACIAL - 2018          Unnamed: 6 Unnamed: 8  \
# 0                             NOME  DATA DE NASCIMENTO    CONTATO
# 1       GABRIEL LUIS REIS DE SOUZA                 NaN        NaN
# 2          LARISSA OLIVEIRA MENDES                 NaN        NaN
# 3       ALANA CRISTINA PESSOA LIMA                 NaN        NaN
# 4             CAIO LUCAS DA SILVA                  NaN        NaN
#
#       Unnamed: 13 Unnamed: 16   Unnamed: 22          Unnamed: 25
# 0  DADOS PESSOAIS      ESCOLA        EVENTO                 DATA
# 1             NaN         NaN  DIA ESPACIAL  2018-03-12 00:00:00
# 2             NaN         NaN  DIA ESPACIAL  2018-03-12 00:00:00
# 3             NaN         NaN  DIA ESPACIAL  2018-03-12 00:00:00
# 4             NaN         NaN  DIA ESPACIAL  2018-03-12 00:00:00

# %%
# renomerar as colunas

tabela_cvt = tabela_cvt.rename(columns={
    'ESTATÍSTICAS CVT-ESPACIAL - 2018': 'NOME',
    'Unnamed: 6': 'DATA DE NASCIMENTO',
    'Unnamed: 8': 'CONTATO',
    'Unnamed: 13': 'DADOS PESSOAIS',
    'Unnamed: 16': 'ESCOLA',
    'Unnamed: 22': 'EVENTO',
    'Unnamed: 25': 'DATA'
})

tabela_cvt = tabela_cvt.reset_index(drop=True)
tabela_cvt = tabela_cvt.drop(index=[0])
display(tabela_cvt)
# Out:
#                                        NOME DATA DE NASCIMENTO  \
# 1                GABRIEL LUIS REIS DE SOUZA                NaN
# 2                   LARISSA OLIVEIRA MENDES                NaN
# 3                ALANA CRISTINA PESSOA LIMA                NaN
# 4                      CAIO LUCAS DA SILVA                 NaN
# 5           GILDERSON GABRIEL DE O. BATISTA                NaN
# ...                                     ...                ...
# 1462  VILLIANY CRISTINI MONTEIRO DE ANDRADE                NaN
# 1463         JOÃO VICTOR VIRGINIO R. DANTAS                NaN
# 1464             JOSÉ CÁSSIO DE ARAUJO GOES                NaN
# 1465                AYTALO CAUÃ DE OLIVEIRA                NaN
# 1466           MARIA ALICE CANDIDO DA SILVA                NaN
#
#                             CONTATO DADOS PESSOAIS  \
# 1                               NaN            NaN
# 2                               NaN            NaN
# 3                               NaN            NaN
# ...

# %%
tabela_cvt = tabela_cvt.drop(columns=['DATA DE NASCIMENTO',  'DADOS PESSOAIS'],errors='ignore')
display(tabela_cvt)
# Out:
#                                        NOME                        CONTATO  \
# 1                GABRIEL LUIS REIS DE SOUZA                            NaN
# 2                   LARISSA OLIVEIRA MENDES                            NaN
# 3                ALANA CRISTINA PESSOA LIMA                            NaN
# 4                      CAIO LUCAS DA SILVA                             NaN
# 5           GILDERSON GABRIEL DE O. BATISTA                            NaN
# ...                                     ...                            ...
# 1462  VILLIANY CRISTINI MONTEIRO DE ANDRADE  villiantandrade2806@gmail.com
# 1463         JOÃO VICTOR VIRGINIO R. DANTAS  victordantasjonny@hotmail.com
# 1464             JOSÉ CÁSSIO DE ARAUJO GOES       josecassio2013@gmail.com
# 1465                AYTALO CAUÃ DE OLIVEIRA       caua.ad.kla321@gmail.com
# 1466           MARIA ALICE CANDIDO DA SILVA          nilcecam@yahoo.com.br
#
# ...

# %%
# excluindo linhas onde todas as colunas nao possuem nenhum valor
tabela_cvt = tabela_cvt.dropna(how='all')
display(tabela_cvt)
# Out:
#                                        NOME                        CONTATO  \
# 1                GABRIEL LUIS REIS DE SOUZA                            NaN
# 2                   LARISSA OLIVEIRA MENDES                            NaN
# 3                ALANA CRISTINA PESSOA LIMA                            NaN
# 4                      CAIO LUCAS DA SILVA                             NaN
# 5           GILDERSON GABRIEL DE O. BATISTA                            NaN
# ...                                     ...                            ...
# 1462  VILLIANY CRISTINI MONTEIRO DE ANDRADE  villiantandrade2806@gmail.com
# 1463         JOÃO VICTOR VIRGINIO R. DANTAS  victordantasjonny@hotmail.com
# 1464             JOSÉ CÁSSIO DE ARAUJO GOES       josecassio2013@gmail.com
# 1465                AYTALO CAUÃ DE OLIVEIRA       caua.ad.kla321@gmail.com
# 1466           MARIA ALICE CANDIDO DA SILVA          nilcecam@yahoo.com.br
#
# ...

# %%
print(tabela_cvt['NOME'].head(100))
# Out:
# 1           GABRIEL LUIS REIS DE SOUZA
# 2              LARISSA OLIVEIRA MENDES
# 3           ALANA CRISTINA PESSOA LIMA
# 4                 CAIO LUCAS DA SILVA
# 5      GILDERSON GABRIEL DE O. BATISTA
#                     ...
# 100    TILERIO GRACCO PAIVA DE AZEVEDO
# 101          TARCISIO RASBALC DA SILVA
# 102    LETÍCIA FERNANDES L. LAURENTINO
# 103             ALEX OLIVEIRA DA SILVA
# 104        JUTIARA SHIRLEY A. O. LOPES
# Name: NOME, Length: 100, dtype: object

# %%
tabela_cvt = tabela_cvt[~tabela_cvt['NOME'].str.contains(r'\((PROFESSOR|RESPONSÁVEL)\)', na=False)]
print(tabela_cvt['NOME'].head(100))
# Out:
# 1           GABRIEL LUIS REIS DE SOUZA
# 2              LARISSA OLIVEIRA MENDES
# 3           ALANA CRISTINA PESSOA LIMA
# 4                 CAIO LUCAS DA SILVA
# 5      GILDERSON GABRIEL DE O. BATISTA
#                     ...
# 101          TARCISIO RASBALC DA SILVA
# 102    LETÍCIA FERNANDES L. LAURENTINO
# 103             ALEX OLIVEIRA DA SILVA
# 104        JUTIARA SHIRLEY A. O. LOPES
# 115            MARIA LORENA P. BATISTA
# Name: NOME, Length: 100, dtype: object
# /tmp/ipython-input-44-4252214110.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   tabela_cvt = tabela_cvt[~tabela_cvt['NOME'].str.contains(r'\((PROFESSOR|RESPONSÁVEL)\)', na=False)]

# %%
display(tabela_cvt)
# Out:
#                                        NOME                        CONTATO  \
# 1                GABRIEL LUIS REIS DE SOUZA                            NaN
# 2                   LARISSA OLIVEIRA MENDES                            NaN
# 3                ALANA CRISTINA PESSOA LIMA                            NaN
# 4                      CAIO LUCAS DA SILVA                             NaN
# 5           GILDERSON GABRIEL DE O. BATISTA                            NaN
# ...                                     ...                            ...
# 1462  VILLIANY CRISTINI MONTEIRO DE ANDRADE  villiantandrade2806@gmail.com
# 1463         JOÃO VICTOR VIRGINIO R. DANTAS  victordantasjonny@hotmail.com
# 1464             JOSÉ CÁSSIO DE ARAUJO GOES       josecassio2013@gmail.com
# 1465                AYTALO CAUÃ DE OLIVEIRA       caua.ad.kla321@gmail.com
# 1466           MARIA ALICE CANDIDO DA SILVA          nilcecam@yahoo.com.br
#
# ...

# %%
# !pip install openpyxl

# %%
tabela_cvt.to_excel("arquivos/tabela_filtrada.xlsx", index=False)

# %%
# trabalhando com a busca dos nomes nas tabelas

nomes_cvt = tabela_cvt['NOME']
display(nomes_cvt)
# Out:
# 1                  GABRIEL LUIS REIS DE SOUZA
# 2                     LARISSA OLIVEIRA MENDES
# 3                  ALANA CRISTINA PESSOA LIMA
# 4                        CAIO LUCAS DA SILVA
# 5             GILDERSON GABRIEL DE O. BATISTA
#                         ...
# 1462    VILLIANY CRISTINI MONTEIRO DE ANDRADE
# 1463           JOÃO VICTOR VIRGINIO R. DANTAS
# 1464               JOSÉ CÁSSIO DE ARAUJO GOES
# 1465                  AYTALO CAUÃ DE OLIVEIRA
# 1466             MARIA ALICE CANDIDO DA SILVA
# Name: NOME, Length: 1347, dtype: object

# %%
tabela_sisu21_1 = pd.read_csv('arquivos/ChamadaRegular_2021-1.csv', sep=';', encoding='latin1', on_bad_lines='skip',
    low_memory=False)
display(tabela_sisu21_1)
# Out:
#         ï»¿NU_ANO  NU_EDICAO  CO_ETAPA     DS_ETAPA  CO_IES  \
# 0            2021          1         4  1Â° CHAMADA     578
# 1            2021          1         4  1Â° CHAMADA     578
# 2            2021          1         4  1Â° CHAMADA     578
# 3            2021          1         4  1Â° CHAMADA     578
# 4            2021          1         4  1Â° CHAMADA     578
# ...           ...        ...       ...          ...     ...
# 397618       2021          1         4  1Â° CHAMADA       8
# 397619       2021          1         4  1Â° CHAMADA    1808
# 397620       2021          1         4  1Â° CHAMADA     578
# 397621       2021          1         4  1Â° CHAMADA    3984
# 397622       2021          1         4  1Â° CHAMADA    5322
#
#                                                    NO_IES SIGLA_IES SG_UF_IES  \
# 0                           UNIVERSIDADE FEDERAL DA BAHIA      UFBA        BA
# 1                           UNIVERSIDADE FEDERAL DA BAHIA      UFBA        BA
# ...

# %%
print(tabela_sisu21_1.columns)
# Out:
# Index(['ï»¿NU_ANO', 'NU_EDICAO', 'CO_ETAPA', 'DS_ETAPA', 'CO_IES', 'NO_IES',
#        'SIGLA_IES', 'SG_UF_IES', 'CO_CAMPUS', 'NO_CAMPUS', 'SG_UF_CAMPUS',
#        'NO_MUNUCIPIO_CAMPUS', 'CO_IES_CURSO', 'NO_CURSO', 'DS_GRAU',
#        'DS_TURNO', 'TP_MOD_CONCORRENCIA', 'DS_MOD_CONCORRENCIA',
#        'NU_PERCENTUAL_BONUS', 'NU_PESO_L', 'NU_PESO_CH', 'NU_PESO_CN',
#        'NU_PESO_M', 'NU_PESO_R', 'NOTA_MINIMA_L', 'NOTA_MINIMA_CH',
#        'NOTA_MINIMA_CN', 'NOTA_MINIMA_M', 'NOTA_MINIMA_R', 'MEDIA_MINIMA',
#        'NU_CPF', 'CO_INSCRICAO_ENEM', 'NO_INSCRITO', 'TP_SEXO',
#        'DT_NASCIMENTO', 'SG_UF_CANDIDATO', 'MUNICIPIO_CANDIDATO', 'ST_OPCAO',
#        'NU_NOTA_L', 'NU_NOTA_CH', 'NU_NOTA_CN', 'NU_NOTA_M', 'NU_NOTA_R',
#        'NOTA_L_COM_PESO', 'NOTA_CH_COM_PESO', 'NOTA_CN_COM_PESO',
#        'NOTA_M_COM_PESO', 'NOTA_R_COM_PESO', 'NU_NOTA_CANDIDATO',
#        'NU_NOTACORTE', 'NU_CLASSIFICACAO', 'ST_APROVADO', 'ST_MATRICULA'],
#       dtype='object')

# %%
nomes_tabela_sisu21_1 = tabela_sisu21_1['NO_INSCRITO']
display(nomes_tabela_sisu21_1)
# Out:
# 0                   RAFAELA DE SOUZA MARTINS
# 1                     ELISABETE SILVA SANTOS
# 2         ROSILENE SILVA OLIVEIRA DOS SANTOS
# 3           MATHEUS DA SILVA BARRETO SANTANA
# 4              MICHAEL FREIRE GOMES DA SILVA
#                          ...
# 397618                         DEBORA CHAGAS
# 397619              JULIA BARBOSA DO ROZARIO
# 397620              YASMINE JESUS DOS SANTOS
# 397621    BEATRIZ CRISTINA FERREIRA DE SOUSA
# 397622                                   NaN
# Name: NO_INSCRITO, Length: 397623, dtype: object

# %%
tabela_sisu21_2 = pd.read_csv('arquivos/ChamadaRegular2021-2.csv', sep='|', encoding='latin1', on_bad_lines='skip',
    low_memory=False)
display(tabela_sisu21_2)
# Out:
#          ANO  EDICAO  ETAPA         DS_ETAPA  CODIGO_IES  \
# 0       2021       2      4  CHAMADA REGULAR         593
# 1       2021       2      4  CHAMADA REGULAR         593
# 2       2021       2      4  CHAMADA REGULAR         593
# 3       2021       2      4  CHAMADA REGULAR         593
# 4       2021       2      4  CHAMADA REGULAR         593
# ...      ...     ...    ...              ...         ...
# 595438  2021       2      4  CHAMADA REGULAR         586
# 595439  2021       2      4  CHAMADA REGULAR         586
# 595440  2021       2      4  CHAMADA REGULAR         586
# 595441  2021       2      4  CHAMADA REGULAR         586
# 595442  2021       2      4  CHAMADA REGULAR         586
#
#                                                  NOME_IES SIGLA_IES UF_IES  \
# 0       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# 1       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# ...

# %%
print(tabela_sisu21_2.columns)
# Out:
# Index(['ANO', 'EDICAO', 'ETAPA', 'DS_ETAPA', 'CODIGO_IES', 'NOME_IES',
#        'SIGLA_IES', 'UF_IES', 'CODIGO_CAMPUS', 'NOME_CAMPUS', 'UF_CAMPUS',
#        'MUNICIPIO_CAMPUS', 'CODIGO_CURSO', 'NOME_CURSO', 'GRAU', 'TURNO',
#        'DS_PERIODICIDADE', 'TP_COTA', 'TIPO_MOD_CONCORRENCIA',
#        'MOD_CONCORRENCIA', 'QT_VAGAS_CONCORRENCIA', 'PERCENTUAL_BONUS',
#        'PESO_L', 'PESO_CH', 'PESO_CN', 'PESO_M', 'PESO_R', 'NOTA_MINIMA_L',
#        'NOTA_MINIMA_CH', 'NOTA_MINIMA_CN', 'NOTA_MINIMA_M', 'NOTA_MINIMA_R',
#        'MEDIA_MINIMA', 'CPF', 'INSCRICAO_ENEM', 'INSCRITO', 'SEXO',
#        'DATA_NASCIMENTO', 'UF_CANDIDATO', 'MUNICIPIO_CANDIDATO', 'OPCAO',
#        'NOTA_L', 'NOTA_CH', 'NOTA_CN', 'NOTA_M', 'NOTA_R', 'NOTA_L_COM_PESO',
#        'NOTA_CH_COM_PESO', 'NOTA_CN_COM_PESO', 'NOTA_M_COM_PESO',
#        'NOTA_R_COM_PESO', 'NOTA_CANDIDATO', 'NOTA_CORTE', 'CLASSIFICACAO',
#        'APROVADO', 'MATRICULA'],
#       dtype='object')

# %%
nomes_tabela_sisu21_2 = tabela_sisu21_2['INSCRITO']
display(nomes_tabela_sisu21_2)
# Out:
# 0                           ADILSON DO CARMO
# 1                      AGATHA GAMBOA MENEZES
# 2                   ALESSANDER PINTO PEIXOTO
# 3               ALEX BARROS VENTAPANE SOARES
# 4                  ALEXANDER MENDES FERREIRA
#                          ...
# 595438             ANA BEATRIZ NEVES DE LIMA
# 595439              ANA BEATRIZ PARGA SANTOS
# 595440           ANA CAROLINA ROCHA DA SILVA
# 595441    ANA CAROLINA VALLADARES DOS SANTOS
# 595442                                   NaN
# Name: INSCRITO, Length: 595443, dtype: object

# %%
tabela_sisu22_1 = pd.read_csv('arquivos/ChamadaRegular2022_1.csv', sep='|', encoding='latin1', on_bad_lines='skip',
    low_memory=False)
display(tabela_sisu22_1)
# Out:
#          ANO  EDICAO  ETAPA         DS_ETAPA  CODIGO_IES  \
# 0       2022       1      4  CHAMADA REGULAR         593
# 1       2022       1      4  CHAMADA REGULAR         593
# 2       2022       1      4  CHAMADA REGULAR         593
# 3       2022       1      4  CHAMADA REGULAR         593
# 4       2022       1      4  CHAMADA REGULAR         593
# ...      ...     ...    ...              ...         ...
# 514051  2022       1      4  CHAMADA REGULAR           9
# 514052  2022       1      4  CHAMADA REGULAR           9
# 514053  2022       1      4  CHAMADA REGULAR           9
# 514054  2022       1      4  CHAMADA REGULAR           9
# 514055  2022       1      4  CHAMADA REGULAR           9
#
#                                                  NOME_IES SIGLA_IES UF_IES  \
# 0       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# 1       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# ...

# %%
print(tabela_sisu22_1.columns)
# Out:
# Index(['ANO', 'EDICAO', 'ETAPA', 'DS_ETAPA', 'CODIGO_IES', 'NOME_IES',
#        'SIGLA_IES', 'UF_IES', 'CODIGO_CAMPUS', 'NOME_CAMPUS', 'UF_CAMPUS',
#        'MUNICIPIO_CAMPUS', 'CODIGO_CURSO', 'NOME_CURSO', 'GRAU', 'TURNO',
#        'DS_PERIODICIDADE', 'TP_COTA', 'TIPO_MOD_CONCORRENCIA',
#        'MOD_CONCORRENCIA', 'QT_VAGAS_CONCORRENCIA', 'PERCENTUAL_BONUS',
#        'PESO_L', 'PESO_CH', 'PESO_CN', 'PESO_M', 'PESO_R', 'NOTA_MINIMA_L',
#        'NOTA_MINIMA_CH', 'NOTA_MINIMA_CN', 'NOTA_MINIMA_M', 'NOTA_MINIMA_R',
#        'MEDIA_MINIMA', 'CPF', 'INSCRICAO_ENEM', 'INSCRITO', 'SEXO',
#        'DATA_NASCIMENTO', 'UF_CANDIDATO', 'MUNICIPIO_CANDIDATO', 'OPCAO',
#        'NOTA_L', 'NOTA_CH', 'NOTA_CN', 'NOTA_M', 'NOTA_R', 'NOTA_L_COM_PESO',
#        'NOTA_CH_COM_PESO', 'NOTA_CN_COM_PESO', 'NOTA_M_COM_PESO',
#        'NOTA_R_COM_PESO', 'NOTA_CANDIDATO', 'NOTA_CORTE', 'CLASSIFICACAO',
#        'APROVADO', 'MATRICULA'],
#       dtype='object')

# %%
nomes_tabela_sisu22_1 = tabela_sisu22_1['INSCRITO']
display(nomes_tabela_sisu22_1)
# Out:
# 0         ABRAAO CARDOSO DO NASCIMENTO JUNIOR
# 1                            ADHAM GREG DIEHL
# 2            ALEX SANDRO DA COSTA SILVA SOUZA
# 3                          ANDRE LOPES BIONDE
# 4         ANDRE LUIZ DE SOUZA FERREIRA JUNIOR
#                          ...
# 514051       MARJANNA BARCZAK DA SILVA CARPES
# 514052         MATHEUS LUIS SILVEIRA DA SILVA
# 514053    MAURICIO MASAYUKI SARUWATARI JUNIOR
# 514054                   MONIQUE NEVES DE LUZ
# 514055                                    NaN
# Name: INSCRITO, Length: 514056, dtype: object

# %%
tabela_sisu22_2 = pd.read_csv('arquivos/ChamadaRegular2022_2.csv', sep='|', encoding='latin1', on_bad_lines='skip',
    low_memory=False)
display(tabela_sisu22_2)
# Out:
#          ANO  EDICAO  ETAPA         DS_ETAPA  CODIGO_IES  \
# 0       2022       2      4  CHAMADA REGULAR         593
# 1       2022       2      4  CHAMADA REGULAR         593
# 2       2022       2      4  CHAMADA REGULAR         593
# 3       2022       2      4  CHAMADA REGULAR         593
# 4       2022       2      4  CHAMADA REGULAR         593
# ...      ...     ...    ...              ...         ...
# 587185  2022       2      4  CHAMADA REGULAR          12
# 587186  2022       2      4  CHAMADA REGULAR          12
# 587187  2022       2      4  CHAMADA REGULAR          12
# 587188  2022       2      4  CHAMADA REGULAR          12
# 587189  2022       2      4  CHAMADA REGULAR          12
#
#                                                  NOME_IES SIGLA_IES UF_IES  \
# 0       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# 1       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# ...

# %%
print(tabela_sisu22_2.columns)
# Out:
# Index(['ANO', 'EDICAO', 'ETAPA', 'DS_ETAPA', 'CODIGO_IES', 'NOME_IES',
#        'SIGLA_IES', 'UF_IES', 'CODIGO_CAMPUS', 'NOME_CAMPUS', 'UF_CAMPUS',
#        'MUNICIPIO_CAMPUS', 'CODIGO_CURSO', 'NOME_CURSO', 'GRAU', 'TURNO',
#        'DS_PERIODICIDADE', 'TP_COTA', 'TIPO_MOD_CONCORRENCIA',
#        'MOD_CONCORRENCIA', 'QT_VAGAS_CONCORRENCIA', 'PERCENTUAL_BONUS',
#        'PESO_L', 'PESO_CH', 'PESO_CN', 'PESO_M', 'PESO_R', 'NOTA_MINIMA_L',
#        'NOTA_MINIMA_CH', 'NOTA_MINIMA_CN', 'NOTA_MINIMA_M', 'NOTA_MINIMA_R',
#        'MEDIA_MINIMA', 'CPF', 'INSCRICAO_ENEM', 'INSCRITO', 'SEXO',
#        'DATA_NASCIMENTO', 'UF_CANDIDATO', 'MUNICIPIO_CANDIDATO', 'OPCAO',
#        'NOTA_L', 'NOTA_CH', 'NOTA_CN', 'NOTA_M', 'NOTA_R', 'NOTA_L_COM_PESO',
#        'NOTA_CH_COM_PESO', 'NOTA_CN_COM_PESO', 'NOTA_M_COM_PESO',
#        'NOTA_R_COM_PESO', 'NOTA_CANDIDATO', 'NOTA_CORTE', 'CLASSIFICACAO',
#        'APROVADO', 'MATRICULA'],
#       dtype='object')

# %%
nomes_tabela_sisu22_2 = tabela_sisu22_2['INSCRITO']
display(nomes_tabela_sisu22_2)
# Out:
# 0          ALEXANDRE CARDOSO DE LEMOS JUNIOR
# 1                 ALEXANDRE MOREIRA DA SILVA
# 2         ALLAN DOUGLAS DE ALMEIDA FRANCISCO
# 3               AMANDA BEATRIZ DA SILVA LIMA
# 4                     AMANDA IZABELA BOBRZYK
#                          ...
# 587185                  HELLEN CRUZ BARRADAS
# 587186                 HELLEN DA CRUZ SANTOS
# 587187           HIGOR BRUNO NOBERTO BEZERRA
# 587188              INGRID OLIVEIRA DA SILVA
# 587189              IORRANA SCHELLIN MULLING
# Name: INSCRITO, Length: 587190, dtype: object

# %%
tabela_sisu23_1 = pd.read_csv('arquivos/ChamadaRegular2023_1.csv', sep='|', encoding='latin1', on_bad_lines='skip',
    low_memory=False)
display(tabela_sisu23_1)
print(tabela_sisu23_1.columns)
nomes_tabela_sisu23_1 = tabela_sisu23_1['INSCRITO']
display(nomes_tabela_sisu23_1)
# Out:
#          ANO  EDICAO  ETAPA         DS_ETAPA  CODIGO_IES  \
# 0       2023       1      4  CHAMADA REGULAR         593
# 1       2023       1      4  CHAMADA REGULAR         593
# 2       2023       1      4  CHAMADA REGULAR         593
# 3       2023       1      4  CHAMADA REGULAR         593
# 4       2023       1      4  CHAMADA REGULAR         593
# ...      ...     ...    ...              ...         ...
# 511169  2023       1      4  CHAMADA REGULAR         609
# 511170  2023       1      4  CHAMADA REGULAR         609
# 511171  2023       1      4  CHAMADA REGULAR         609
# 511172  2023       1      4  CHAMADA REGULAR         609
# 511173  2023       1      4  CHAMADA REGULAR         609
#
#                                                  NOME_IES SIGLA_IES UF_IES  \
# 0       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# 1       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# ...

# %%
tabela_sisu23_2 = pd.read_csv('arquivos/ChamadaRegular2023_2.csv', sep='|', encoding='latin1', on_bad_lines='skip',
    low_memory=False)
display(tabela_sisu23_2)
print(tabela_sisu23_2.columns)
nomes_tabela_sisu23_2 = tabela_sisu23_2['INSCRITO']
display(nomes_tabela_sisu23_2)
# Out:
#          ANO  EDICAO  ETAPA         DS_ETAPA  CODIGO_IES  \
# 0       2023       2      4  CHAMADA REGULAR         593
# 1       2023       2      4  CHAMADA REGULAR         593
# 2       2023       2      4  CHAMADA REGULAR         593
# 3       2023       2      4  CHAMADA REGULAR         593
# 4       2023       2      4  CHAMADA REGULAR         593
# ...      ...     ...    ...              ...         ...
# 578776  2023       2      4  CHAMADA REGULAR         588
# 578777  2023       2      4  CHAMADA REGULAR         588
# 578778  2023       2      4  CHAMADA REGULAR         588
# 578779  2023       2      4  CHAMADA REGULAR         588
# 578780  2023       2      4  CHAMADA REGULAR         588
#
#                                                  NOME_IES SIGLA_IES UF_IES  \
# 0       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# 1       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# ...

# %%
import csv
lista_espera_sisu21_1 = pd.read_csv('arquivos/ListaEspera2021-1.csv', sep='|', encoding='latin1', on_bad_lines='skip',quoting=csv.QUOTE_NONE,
    low_memory=False)
display(lista_espera_sisu21_1)
print(lista_espera_sisu21_1.columns)
nomes_lista_espera_sisu21_1 = lista_espera_sisu21_1['"NO_INSCRITO"']
display(nomes_lista_espera_sisu21_1)
# Out:
#         "NU_ANO"  "NU_EDICAO"  "CO_ETAPA"         "DS_ETAPA"  "CO_IES"  \
# 0           2021            1           7  "LISTA DE ESPERA"         3
# 1           2021            1           7  "LISTA DE ESPERA"         3
# 2           2021            1           7  "LISTA DE ESPERA"         3
# 3           2021            1           7  "LISTA DE ESPERA"         3
# 4           2021            1           7  "LISTA DE ESPERA"         3
# ...          ...          ...         ...                ...       ...
# 173086      2021            1           7  "LISTA DE ESPERA"         5
# 173087      2021            1           7  "LISTA DE ESPERA"       580
# 173088      2021            1           7  "LISTA DE ESPERA"         5
# 173089      2021            1           7  "LISTA DE ESPERA"       756
# 173090      2021            1           7  "LISTA DE ESPERA"       600
#
#                                                  "NO_IES" "SIGLA_IES"  \
# ...

# %%
# Remove aspas duplas dos nomes
nomes_lista_espera_sisu21_1 = nomes_lista_espera_sisu21_1.str.strip('"')
display(nomes_lista_espera_sisu21_1)
# Out:
# 0                MARCELO VICTOR SANTOS SOUZA
# 1                 RAMON PABLO ALVES DE SOUSA
# 2                  MARIA GRACIELE DOS SANTOS
# 3                     VICTORIA GOULART ALVES
# 4           VITORIA MINELVINA SANTOS MARQUES
#                          ...
# 173086           JODIE EMILLY CUNHA DE SOUSA
# 173087          THALYSSA JANUARIO DOS SANTOS
# 173088    FRANCISCO CLAYVERTHE DO NASCIMENTO
# 173089              MARIANA PEREIRA OLIVEIRA
# 173090                                   NaN
# Name: "NO_INSCRITO", Length: 173091, dtype: object

# %%
lista_espera_sisu21_2 = pd.read_csv('arquivos/ListaEspera_2021-2.csv', sep='|', encoding='latin1', on_bad_lines='skip',
    low_memory=False)
display(lista_espera_sisu21_2)
print(lista_espera_sisu21_2.columns)
nomes_lista_espera_sisu21_2 = lista_espera_sisu21_2['INSCRITO']
display(nomes_lista_espera_sisu21_2)
# Out:
#          ANO  EDICAO  ETAPA         DS_ETAPA  CODIGO_IES  \
# 0       2021       2      7  LISTA DE ESPERA         593
# 1       2021       2      7  LISTA DE ESPERA         593
# 2       2021       2      7  LISTA DE ESPERA         593
# 3       2021       2      7  LISTA DE ESPERA         593
# 4       2021       2      7  LISTA DE ESPERA         593
# ...      ...     ...    ...              ...         ...
# 189830  2021       2      7  LISTA DE ESPERA         588
# 189831  2021       2      7  LISTA DE ESPERA         588
# 189832  2021       2      7  LISTA DE ESPERA         588
# 189833  2021       2      7  LISTA DE ESPERA         588
# 189834  2021       2      7  LISTA DE ESPERA         588
#
#                                                  NOME_IES SIGLA_IES UF_IES  \
# 0       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# 1       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# ...

# %%
lista_espera_sisu22_1 = pd.read_csv('arquivos/ListaEspera2022_1.csv', sep='|', encoding='latin1', on_bad_lines='skip',
    low_memory=False)
display(lista_espera_sisu22_1)
print(lista_espera_sisu22_1.columns)
nomes_lista_espera_sisu22_1 = lista_espera_sisu22_1['INSCRITO']
display(nomes_lista_espera_sisu22_1)
# Out:
#          ANO  EDICAO  ETAPA         DS_ETAPA  CODIGO_IES  \
# 0       2022       1      7  LISTA DE ESPERA         593
# 1       2022       1      7  LISTA DE ESPERA         593
# 2       2022       1      7  LISTA DE ESPERA         593
# 3       2022       1      7  LISTA DE ESPERA         593
# 4       2022       1      7  LISTA DE ESPERA         593
# ...      ...     ...    ...              ...         ...
# 155147  2022       1      7  LISTA DE ESPERA          32
# 155148  2022       1      7  LISTA DE ESPERA          32
# 155149  2022       1      7  LISTA DE ESPERA          32
# 155150  2022       1      7  LISTA DE ESPERA          32
# 155151  2022       1      7  LISTA DE ESPERA          32
#
#                                                  NOME_IES SIGLA_IES UF_IES  \
# 0       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# 1       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# ...

# %%
lista_espera_sisu22_2 = pd.read_csv('arquivos/ListaEspera2022_2.csv', sep='|', encoding='latin1', on_bad_lines='skip',
    low_memory=False)
display(lista_espera_sisu22_2)
print(lista_espera_sisu22_2.columns)
nomes_lista_espera_sisu22_2 = lista_espera_sisu22_2['INSCRITO']
display(nomes_lista_espera_sisu22_2)
# Out:
#          ANO  EDICAO  ETAPA         DS_ETAPA  CODIGO_IES  \
# 0       2022       2      7  LISTA DE ESPERA         593
# 1       2022       2      7  LISTA DE ESPERA         593
# 2       2022       2      7  LISTA DE ESPERA         593
# 3       2022       2      7  LISTA DE ESPERA         593
# 4       2022       2      7  LISTA DE ESPERA         593
# ...      ...     ...    ...              ...         ...
# 184202  2022       2      7  LISTA DE ESPERA         588
# 184203  2022       2      7  LISTA DE ESPERA         588
# 184204  2022       2      7  LISTA DE ESPERA         588
# 184205  2022       2      7  LISTA DE ESPERA         588
# 184206  2022       2      7  LISTA DE ESPERA         588
#
#                                                  NOME_IES SIGLA_IES UF_IES  \
# 0       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# 1       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# ...

# %%
lista_espera_sisu23_1 = pd.read_csv('arquivos/ListaEspera2023_1.csv', sep='|', encoding='latin1', on_bad_lines='skip',
    low_memory=False)
display(lista_espera_sisu23_1)
print(lista_espera_sisu23_1.columns)
nomes_lista_espera_sisu23_1 = lista_espera_sisu23_1['INSCRITO']
display(nomes_lista_espera_sisu23_1)
# Out:
#          ANO  EDICAO  ETAPA         DS_ETAPA  CODIGO_IES  \
# 0       2023       1      7  LISTA DE ESPERA         593
# 1       2023       1      7  LISTA DE ESPERA         593
# 2       2023       1      7  LISTA DE ESPERA         593
# 3       2023       1      7  LISTA DE ESPERA         593
# 4       2023       1      7  LISTA DE ESPERA         593
# ...      ...     ...    ...              ...         ...
# 604847  2023       1      7  LISTA DE ESPERA         588
# 604848  2023       1      7  LISTA DE ESPERA         588
# 604849  2023       1      7  LISTA DE ESPERA         588
# 604850  2023       1      7  LISTA DE ESPERA         588
# 604851  2023       1      7  LISTA DE ESPERA         588
#
#                                                  NOME_IES SIGLA_IES UF_IES  \
# 0       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# 1       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# ...

# %%
lista_espera_sisu23_2 = pd.read_csv('arquivos/ListaEspera2023_2.csv', sep='|', encoding='latin1', on_bad_lines='skip',
    low_memory=False)
display(lista_espera_sisu23_2)
print(lista_espera_sisu23_2.columns)
nomes_lista_espera_sisu23_2 = lista_espera_sisu23_2['INSCRITO']
display(nomes_lista_espera_sisu23_2)
# Out:
#          ANO  EDICAO  ETAPA         DS_ETAPA  CODIGO_IES  \
# 0       2023       2      7  LISTA DE ESPERA         593
# 1       2023       2      7  LISTA DE ESPERA         593
# 2       2023       2      7  LISTA DE ESPERA         593
# 3       2023       2      7  LISTA DE ESPERA         593
# 4       2023       2      7  LISTA DE ESPERA         593
# ...      ...     ...    ...              ...         ...
# 148768  2023       2      7  LISTA DE ESPERA         588
# 148769  2023       2      7  LISTA DE ESPERA         588
# 148770  2023       2      7  LISTA DE ESPERA         588
# 148771  2023       2      7  LISTA DE ESPERA         588
# 148772  2023       2      7  LISTA DE ESPERA         588
#
#                                                  NOME_IES SIGLA_IES UF_IES  \
# 0       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# 1       CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA CELSO S...  CEFET/RJ     RJ
# ...

# %%
discentesuf21 = pd.read_csv('arquivos/discentes-UF-2021.csv', sep=';')
display(discentesuf21)
print(discentesuf21.columns)
nomes_discentesuf21 = discentesuf21['nome_discente']
display(nomes_discentesuf21)
# Out:
#          matricula  ano_ingresso  periodo_ingresso     id_curso  id_unidade  \
# 0      20210022063          2021               1.0   10320810.0      4885.0
# 1      20210023632          2021               1.0  111635041.0       441.0
# 2      20213003885          2021               0.0   89236989.0       351.0
# 3      20210060144          2021               2.0  118834827.0       442.0
# 4      20210031198          2021               1.0    2000018.0       443.0
# ...            ...           ...               ...          ...         ...
# 15204  20210020354          2021               1.0    2000011.0       443.0
# 15205  20211011690          2021               1.0          NaN         NaN
# 15206  20211021570          2021               2.0     315745.0       363.0
# 15207  20212005277          2021               2.0  148595405.0       138.0
# 15208  20210006382          2021               1.0   50852239.0       442.0
#
# ...

# %%
discentesuf22 = pd.read_csv('arquivos/discentes-UF-2022.csv', sep=';')
display(discentesuf22)
print(discentesuf22.columns)
nomes_discentesuf22 = discentesuf22['nome_discente']
display(nomes_discentesuf22)
# Out:
#          matricula  ano_ingresso  periodo_ingresso     id_curso  id_unidade  \
# 0      20220017174          2022               1.0    2071220.0       445.0
# 1      20220057240          2022               2.0    2000031.0       445.0
# 2      20220046390          2022               1.0  149717829.0     30304.0
# 3      20220077682          2022               2.0          NaN         NaN
# 4      20223009354          2022               1.0   96054058.0      6069.0
# ...            ...           ...               ...          ...         ...
# 14956  20220057447          2022               1.0    2000044.0      1482.0
# 14957  20220069036          2022               1.0  149717829.0     30304.0
# 14958  20221011694          2022               1.0     315728.0       388.0
# 14959  20222002410          2022               1.0  149096769.0       235.0
# 14960  20223001973          2022               1.0  146100906.0       351.0
#
# ...

# %%
discentesuf23 = pd.read_csv('arquivos/discentes-UF-2023.csv', sep=';')
display(discentesuf23)
print(discentesuf23.columns)
nomes_discentesuf23 = discentesuf23['nome_discente']
display(nomes_discentesuf23)
# Out:
#          matricula  ano_ingresso  periodo_ingresso     id_curso  id_unidade  \
# 0      20233002230          2023                 1    1086001.0       205.0
# 1      20230030993          2023                 1    2000063.0      5965.0
# 2      20230060268          2023                 1    2000011.0       443.0
# 3      20233003102          2023                 2  104411100.0       205.0
# 4      20235004065          2023                 1   86979169.0      6042.0
# ...            ...           ...               ...          ...         ...
# 17163  20230012313          2023                 1    9295710.0       440.0
# 17164  20232014021          2023                 2  168441602.0     30546.0
# 17165  20232004419          2023                 1  165508257.0     31011.0
# 17166  20230002685          2023                 1   92127264.0      6069.0
# 17167  20235010151          2023                 2   86979169.0      6042.0
#
# ...

# %%
# !pip install rapidfuzz

# %%
print(tabela_sisu21_1.columns)
# Out:
# Index(['ï»¿NU_ANO', 'NU_EDICAO', 'CO_ETAPA', 'DS_ETAPA', 'CO_IES', 'NO_IES',
#        'SIGLA_IES', 'SG_UF_IES', 'CO_CAMPUS', 'NO_CAMPUS', 'SG_UF_CAMPUS',
#        'NO_MUNUCIPIO_CAMPUS', 'CO_IES_CURSO', 'NO_CURSO', 'DS_GRAU',
#        'DS_TURNO', 'TP_MOD_CONCORRENCIA', 'DS_MOD_CONCORRENCIA',
#        'NU_PERCENTUAL_BONUS', 'NU_PESO_L', 'NU_PESO_CH', 'NU_PESO_CN',
#        'NU_PESO_M', 'NU_PESO_R', 'NOTA_MINIMA_L', 'NOTA_MINIMA_CH',
#        'NOTA_MINIMA_CN', 'NOTA_MINIMA_M', 'NOTA_MINIMA_R', 'MEDIA_MINIMA',
#        'NU_CPF', 'CO_INSCRICAO_ENEM', 'NO_INSCRITO', 'TP_SEXO',
#        'DT_NASCIMENTO', 'SG_UF_CANDIDATO', 'MUNICIPIO_CANDIDATO', 'ST_OPCAO',
#        'NU_NOTA_L', 'NU_NOTA_CH', 'NU_NOTA_CN', 'NU_NOTA_M', 'NU_NOTA_R',
#        'NOTA_L_COM_PESO', 'NOTA_CH_COM_PESO', 'NOTA_CN_COM_PESO',
#        'NOTA_M_COM_PESO', 'NOTA_R_COM_PESO', 'NU_NOTA_CANDIDATO',
#        'NU_NOTACORTE', 'NU_CLASSIFICACAO', 'ST_APROVADO', 'ST_MATRICULA'],
#       dtype='object')

# %%
tabela_sisu21_1['SG_UF_CAMPUS'].head()
# Out:
# 0    BA
# 1    BA
# 2    BA
# 3    BA
# 4    BA
# Name: SG_UF_CAMPUS, dtype: object

# %%
import pandas as pd
from rapidfuzz import process, fuzz

# Padroniza os nomes
nomes_cvt = nomes_cvt.str.upper().str.strip()
nomes_tabela_sisu21_1 = nomes_tabela_sisu21_1 .str.upper().str.strip()

# Lista para armazenar os resultados
resultados = []

# Loop para cada nome da lista do CVT
for nome_aluno in nomes_cvt:
    # Busca o nome mais parecido na base do SISU
    resultado = process.extractOne(
        nome_aluno,
        nomes_tabela_sisu21_1,
        scorer=fuzz.ratio
    )

    # Se a similaridade for ≥ 90, salva os dados
    if resultado and resultado[1] >= 95:
        nome_correspondente = resultado[0]

        # Pega os dados da linha correspondente na base do SISU
        linha = tabela_sisu21_1[nomes_tabela_sisu21_1== nome_correspondente].iloc[0]

        # Adiciona os dados à lista de resultados
        resultados.append({
            'nome_original': nome_aluno,
            'nome_correspondente': nome_correspondente,
            'curso': linha['NO_CURSO'],
            'instituicao': linha['SG_UF_CAMPUS'],
            'situacao': linha['ST_APROVADO']
        })

# Salva os resultados em CSV
df_resultados = pd.DataFrame(resultados)
df_resultados.to_csv('alunos_encontrados_sisu_21_1.csv', index=False)

# %%
alunos_encontrados_sisu21_1 = pd.read_csv('alunos_encontrados_sisu_21_1.csv')
display(alunos_encontrados_sisu21_1)
# Out:
#                            nome_original  \
# 0   FRANCISCA LETICIA DE OLIVEIRA MENDES
# 1            MATHEUS DE OLIVEIRA BARBOSA
# 2           PEDRO HENRIQUE DE LIMA SOUSA
# 3                  LUANA DE MELO SARAIVA
# 4             NATÁLIA PEREIRA DOS SANTOS
# ..                                   ...
# 85                 JOEU OLIVEIRA DE LIMA
# 86              FERNANDA ARAUJO FERREIRA
# 87         FERNANDA KELLY GOMES DA SILVA
# 88             FELIPE FRANCISCO DA SILVA
# 89         ANA BEATRIZ MARTINS RODRIGUES
#
#                      nome_correspondente  \
# 0   FRANCISCA LETICIA DE OLIVEIRA MENDES
# 1            MATHEUS DE OLIVEIRA BARBOSA
# 2           PEDRO HENRIQUE DE LIMA SOUSA
# 3                  LUANA DE MELO SARAIVA
# 4             NATALIA PEREIRA DOS SANTOS
# ..                                   ...
# 85                 JOEL OLIVEIRA DE LIMA
# 86              FERNANDA ARAUJO FERREIRA
# 87         FERNANDA KELLY GOMES DA SILVA
# 88             FELIPE FRANCISCO DA SILVA
# ...

# %%
# Corrigindo o problema da mal formataçao dos nomes dos cursos da coluna cursos
alunos_encontrados_sisu21_1['curso'] = alunos_encontrados_sisu21_1['curso'].apply(lambda x: x.encode('latin1').decode('utf-8') if pd.notnull(x) else x)

# %%
display(alunos_encontrados_sisu21_1)
# Out:
#                            nome_original  \
# 0   FRANCISCA LETICIA DE OLIVEIRA MENDES
# 1            MATHEUS DE OLIVEIRA BARBOSA
# 2           PEDRO HENRIQUE DE LIMA SOUSA
# 3                  LUANA DE MELO SARAIVA
# 4             NATÁLIA PEREIRA DOS SANTOS
# ..                                   ...
# 85                 JOEU OLIVEIRA DE LIMA
# 86              FERNANDA ARAUJO FERREIRA
# 87         FERNANDA KELLY GOMES DA SILVA
# 88             FELIPE FRANCISCO DA SILVA
# 89         ANA BEATRIZ MARTINS RODRIGUES
#
#                      nome_correspondente  \
# 0   FRANCISCA LETICIA DE OLIVEIRA MENDES
# 1            MATHEUS DE OLIVEIRA BARBOSA
# 2           PEDRO HENRIQUE DE LIMA SOUSA
# 3                  LUANA DE MELO SARAIVA
# 4             NATALIA PEREIRA DOS SANTOS
# ..                                   ...
# 85                 JOEL OLIVEIRA DE LIMA
# 86              FERNANDA ARAUJO FERREIRA
# 87         FERNANDA KELLY GOMES DA SILVA
# 88             FELIPE FRANCISCO DA SILVA
# ...

# %%
print(tabela_sisu21_2.columns)
# Out:
# Index(['ANO', 'EDICAO', 'ETAPA', 'DS_ETAPA', 'CODIGO_IES', 'NOME_IES',
#        'SIGLA_IES', 'UF_IES', 'CODIGO_CAMPUS', 'NOME_CAMPUS', 'UF_CAMPUS',
#        'MUNICIPIO_CAMPUS', 'CODIGO_CURSO', 'NOME_CURSO', 'GRAU', 'TURNO',
#        'DS_PERIODICIDADE', 'TP_COTA', 'TIPO_MOD_CONCORRENCIA',
#        'MOD_CONCORRENCIA', 'QT_VAGAS_CONCORRENCIA', 'PERCENTUAL_BONUS',
#        'PESO_L', 'PESO_CH', 'PESO_CN', 'PESO_M', 'PESO_R', 'NOTA_MINIMA_L',
#        'NOTA_MINIMA_CH', 'NOTA_MINIMA_CN', 'NOTA_MINIMA_M', 'NOTA_MINIMA_R',
#        'MEDIA_MINIMA', 'CPF', 'INSCRICAO_ENEM', 'INSCRITO', 'SEXO',
#        'DATA_NASCIMENTO', 'UF_CANDIDATO', 'MUNICIPIO_CANDIDATO', 'OPCAO',
#        'NOTA_L', 'NOTA_CH', 'NOTA_CN', 'NOTA_M', 'NOTA_R', 'NOTA_L_COM_PESO',
#        'NOTA_CH_COM_PESO', 'NOTA_CN_COM_PESO', 'NOTA_M_COM_PESO',
#        'NOTA_R_COM_PESO', 'NOTA_CANDIDATO', 'NOTA_CORTE', 'CLASSIFICACAO',
#        'APROVADO', 'MATRICULA'],
#       dtype='object')

# %%
import pandas as pd
from rapidfuzz import process, fuzz

# Padroniza os nomes da lista CVT
nomes_cvt = nomes_cvt.str.upper().str.strip()

# Padroniza a coluna de nomes do DataFrame original
tabela_sisu21_2['nome_upper'] = nomes_tabela_sisu21_2.str.upper().str.strip()

resultados = []

for nome_aluno in nomes_cvt:
    resultado = process.extractOne(
        nome_aluno,
        tabela_sisu21_2['nome_upper'],
        scorer=fuzz.ratio
    )

    if resultado and resultado[1] >= 95:
        nome_correspondente = resultado[0]

        # Agora filtra usando a coluna já dentro do DataFrame com índice alinhado
        linha = tabela_sisu21_2[tabela_sisu21_2['nome_upper'] == nome_correspondente].iloc[0]

        resultados.append({
            'nome_original': nome_aluno,
            'nome_correspondente': nome_correspondente,
            'curso': linha['NOME_CURSO'],
            'instituicao': linha['UF_CAMPUS'],
            'situacao': linha['APROVADO']
        })

df_resultados = pd.DataFrame(resultados)
df_resultados.to_csv('alunos_encontrados_sisu_21_2.csv', index=False)

# %%
alunos_encontrados_sisu21_2 = pd.read_csv('alunos_encontrados_sisu_21_2.csv')
display(alunos_encontrados_sisu21_2)
# Out:
#                        nome_original               nome_correspondente  \
# 0                CAIO LUCAS DA SILVA               CAIO LUCAS DA SILVA
# 1       LEONARDO CARVALHO DOS SANTOS      LEONARDO CARVALHO DOS SANTOS
# 2            EVERTON PEREIRA DE LIMA           EVERTON PEREIRA DE LIMA
# 3                LUAN COSTA DA SILVA              LUANA COSTA DA SILVA
# 4       ANA CAROLINA RODRIGUES COSTA      ANA CAROLINA RODRIGUES COSTA
# ..                               ...                               ...
# 67            MARIANA BEZERRA DA LUZ            MARIANA BEZERRA DA LUZ
# 68           LARISSA RAIANY DA SILVA           LARISSA RAIANE DA SILVA
# 69  ANNA CAROLINE DE ARAÚJO SANTIAGO  ANNA CAROLINE DE ARAUJO SANTIAGO
# 70         GABRIEL VIANA DE MEDEIROS         GABRIEL VIANA DE MEDEIROS
# 71            JÒFIA RIBEIRO DA SILVA            JAFIA RIBEIRO DA SILVA
#
#                      curso instituicao situacao
# 0    CIÊNCIA DA COMPUTAÇÃO          PR        N
# ...

# %%
print(tabela_sisu22_1.columns)
# Out:
# Index(['ANO', 'EDICAO', 'ETAPA', 'DS_ETAPA', 'CODIGO_IES', 'NOME_IES',
#        'SIGLA_IES', 'UF_IES', 'CODIGO_CAMPUS', 'NOME_CAMPUS', 'UF_CAMPUS',
#        'MUNICIPIO_CAMPUS', 'CODIGO_CURSO', 'NOME_CURSO', 'GRAU', 'TURNO',
#        'DS_PERIODICIDADE', 'TP_COTA', 'TIPO_MOD_CONCORRENCIA',
#        'MOD_CONCORRENCIA', 'QT_VAGAS_CONCORRENCIA', 'PERCENTUAL_BONUS',
#        'PESO_L', 'PESO_CH', 'PESO_CN', 'PESO_M', 'PESO_R', 'NOTA_MINIMA_L',
#        'NOTA_MINIMA_CH', 'NOTA_MINIMA_CN', 'NOTA_MINIMA_M', 'NOTA_MINIMA_R',
#        'MEDIA_MINIMA', 'CPF', 'INSCRICAO_ENEM', 'INSCRITO', 'SEXO',
#        'DATA_NASCIMENTO', 'UF_CANDIDATO', 'MUNICIPIO_CANDIDATO', 'OPCAO',
#        'NOTA_L', 'NOTA_CH', 'NOTA_CN', 'NOTA_M', 'NOTA_R', 'NOTA_L_COM_PESO',
#        'NOTA_CH_COM_PESO', 'NOTA_CN_COM_PESO', 'NOTA_M_COM_PESO',
#        'NOTA_R_COM_PESO', 'NOTA_CANDIDATO', 'NOTA_CORTE', 'CLASSIFICACAO',
#        'APROVADO', 'MATRICULA', 'nome_upper'],
#       dtype='object')

# %%
import pandas as pd
from rapidfuzz import process, fuzz

# Padroniza os nomes da lista CVT
nomes_cvt = nomes_cvt.str.upper().str.strip()

# Padroniza a coluna de nomes do DataFrame original
tabela_sisu22_1['nome_upper'] = nomes_tabela_sisu22_1.str.upper().str.strip()

resultados = []

for nome_aluno in nomes_cvt:
    resultado = process.extractOne(
        nome_aluno,
        tabela_sisu22_1['nome_upper'],
        scorer=fuzz.ratio
    )

    if resultado and resultado[1] >= 95:
        nome_correspondente = resultado[0]

        # Agora filtra usando a coluna já dentro do DataFrame com índice alinhado
        linha = tabela_sisu22_1[tabela_sisu22_1['nome_upper'] == nome_correspondente].iloc[0]

        resultados.append({
            'nome_original': nome_aluno,
            'nome_correspondente': nome_correspondente,
            'curso': linha['NOME_CURSO'],
            'instituicao': linha['UF_CAMPUS'],
            'situacao': linha['APROVADO']
        })

df_resultados = pd.DataFrame(resultados)
df_resultados.to_csv('alunos_encontrados_sisu_22_1.csv', index=False)

# %%
alunos_encontrados_sisu22_1 = pd.read_csv('alunos_encontrados_sisu_22_1.csv')
display(alunos_encontrados_sisu22_1)
# Out:
#                        nome_original              nome_correspondente  \
# 0                  PEDRO SILVA VIANA                PEDRO SILVA VIANA
# 1         PEDRO FELIPE GOMES PEREIRA       PEDRO FELIPE GOMES PEREIRA
# 2       LEONARDO CARVALHO DOS SANTOS     LEONARDO CARVALHO DOS SANTOS
# 3       PEDRO HENRIQUE DE LIMA SOUSA     PEDRO HENRIQUE DE LIMA SOUSA
# 4            EVERTON PEREIRA DE LIMA          EVERTON PEREIRA DE LIMA
# ..                               ...                              ...
# 117    ERICK GABRIEL DUARTE FERONIMO    ERICK GABRIEL DUARTE JERONIMO
# 118  MARIA EDUARDA FLORENCIO PEREIRA  MARIA EDUARDA FLORENCIO PEREIRA
# 119           VINÍCIUS DE LIMA SILVA           VINICIUS DE LIMA SILVA
# 120  MARIA EDUARDA SANTIAGO DA SILVA  MARIA EDUARDA SANTIAGO DA SILVA
# 121         GIOVANNA PEREIRA MARQUES         GIOVANNA PEREIRA MARQUES
#
#                                                  curso instituicao situacao
# ...

# %%
import pandas as pd
from rapidfuzz import process, fuzz

# Padroniza os nomes da lista CVT
nomes_cvt = nomes_cvt.str.upper().str.strip()

# Padroniza a coluna de nomes do DataFrame original
tabela_sisu22_2['nome_upper'] = nomes_tabela_sisu22_2.str.upper().str.strip()

resultados = []

for nome_aluno in nomes_cvt:
    resultado = process.extractOne(
        nome_aluno,
        tabela_sisu22_2['nome_upper'],
        scorer=fuzz.ratio
    )

    if resultado and resultado[1] >= 95:
        nome_correspondente = resultado[0]

        # Agora filtra usando a coluna já dentro do DataFrame com índice alinhado
        linha = tabela_sisu22_2[tabela_sisu22_2['nome_upper'] == nome_correspondente].iloc[0]

        resultados.append({
            'nome_original': nome_aluno,
            'nome_correspondente': nome_correspondente,
            'curso': linha['NOME_CURSO'],
            'instituicao': linha['UF_CAMPUS'],
            'situacao': linha['APROVADO']
        })

df_resultados = pd.DataFrame(resultados)
df_resultados.to_csv('alunos_encontrados_sisu_22_2.csv', index=False)
alunos_encontrados_sisu22_2 = pd.read_csv('alunos_encontrados_sisu_22_2.csv')
display(alunos_encontrados_sisu22_2)
# Out:
#                             nome_original  \
# 0                 LARISSA OLIVEIRA MENDES
# 1    FRANCISCA LETICIA DE OLIVEIRA MENDES
# 2               LUIZA RAQUEL BARROS SILVA
# 3              PEDRO FELIPE GOMES PEREIRA
# 4            LEONARDO CARVALHO DOS SANTOS
# ..                                    ...
# 118                MARIANA BEZERRA DA LUZ
# 119             FELIPE FRANCISCO DA SILVA
# 120               GABRIELA DE SOUZA FELIX
# 121       GABRIEL FELIPE PEREIRA DA SILVA
# 122              ANA FABIA BRITO DA SILVA
#
#                       nome_correspondente                    curso  \
# 0                 LARISSA OLIVEIRA MENDES       CIÊNCIAS CONTÁBEIS
# 1    FRANCISCA LETICIA DE OLIVEIRA MENDES      ENERGIAS RENOVÁVEIS
# 2               LUIZA RAQUEL BARROS SILVA                 MEDICINA
# 3              PEDRO FELIPE GOMES PEREIRA                   FÍSICA
# 4            LEONARDO CARVALHO DOS SANTOS      ENGENHARIA ELÉTRICA
# ...

# %%
import pandas as pd
from rapidfuzz import process, fuzz

# Padroniza os nomes da lista CVT
nomes_cvt = nomes_cvt.str.upper().str.strip()

# Padroniza a coluna de nomes do DataFrame original
tabela_sisu23_1['nome_upper'] = nomes_tabela_sisu23_1.str.upper().str.strip()

resultados = []

for nome_aluno in nomes_cvt:
    resultado = process.extractOne(
        nome_aluno,
        tabela_sisu23_1['nome_upper'],
        scorer=fuzz.ratio
    )

    if resultado and resultado[1] >= 97:
        nome_correspondente = resultado[0]

        # Agora filtra usando a coluna já dentro do DataFrame com índice alinhado
        linha = tabela_sisu23_1[tabela_sisu23_1['nome_upper'] == nome_correspondente].iloc[0]

        resultados.append({
            'nome_original': nome_aluno,
            'nome_correspondente': nome_correspondente,
            'curso': linha['NOME_CURSO'],
            'instituicao': linha['UF_CAMPUS'],
            'situacao': linha['APROVADO']
        })

df_resultados = pd.DataFrame(resultados)
df_resultados.to_csv('alunos_encontrados_sisu_23_1.csv', index=False)
alunos_encontrados_sisu23_1 = pd.read_csv('alunos_encontrados_sisu_23_1.csv')
display(alunos_encontrados_sisu23_1)
# Out:
#                             nome_original  \
# 0                 LARISSA OLIVEIRA MENDES
# 1                     CAIO LUCAS DA SILVA
# 2    FRANCISCA LETICIA DE OLIVEIRA MENDES
# 3             MATHEUS DE OLIVEIRA BARBOSA
# 4                     LUAN COSTA DA SILVA
# ..                                    ...
# 75       PEDRO HENRIQUE DA SILVA PINHEIRO
# 76          ANA BEATRIZ MARTINS RODRIGUES
# 77                GABRIELA DE SOUZA FELIX
# 78          ANA MELISSA LUCENA DE ALENCAR
# 79  VILLIANY CRISTINI MONTEIRO DE ANDRADE
#
#                       nome_correspondente                             curso  \
# 0                 LARISSA OLIVEIRA MENDES                         AGRONOMIA
# 1                     CAIO LUCAS DA SILVA                         AGRONOMIA
# 2    FRANCISCA LETICIA DE OLIVEIRA MENDES               ENERGIAS RENOVÁVEIS
# 3             MATHEUS DE OLIVEIRA BARBOSA                      FISIOTERAPIA
# ...

# %%
import pandas as pd
from rapidfuzz import process, fuzz

# Padroniza os nomes da lista CVT
nomes_cvt = nomes_cvt.str.upper().str.strip()

# Padroniza a coluna de nomes do DataFrame original
tabela_sisu23_2['nome_upper'] = nomes_tabela_sisu23_2.str.upper().str.strip()

resultados = []

for nome_aluno in nomes_cvt:
    resultado = process.extractOne(
        nome_aluno,
        tabela_sisu23_2['nome_upper'],
        scorer=fuzz.ratio
    )

    if resultado and resultado[1] >= 97:
        nome_correspondente = resultado[0]

        # Agora filtra usando a coluna já dentro do DataFrame com índice alinhado
        linha = tabela_sisu23_2[tabela_sisu23_2['nome_upper'] == nome_correspondente].iloc[0]

        resultados.append({
            'nome_original': nome_aluno,
            'nome_correspondente': nome_correspondente,
            'curso': linha['NOME_CURSO'],
            'instituicao': linha['UF_CAMPUS'],
            'situacao': linha['APROVADO']
        })

df_resultados = pd.DataFrame(resultados)
df_resultados.to_csv('alunos_encontrados_sisu_23_2.csv', index=False)
alunos_encontrados_sisu23_2 = pd.read_csv('alunos_encontrados_sisu_23_2.csv')
display(alunos_encontrados_sisu23_2)
# Out:
#                       nome_original              nome_correspondente  \
# 0           LARISSA OLIVEIRA MENDES          LARISSA OLIVEIRA MENDES
# 1               CAIO LUCAS DA SILVA              CAIO LUCAS DA SILVA
# 2          PEDRO GUILHERME DA SILVA         PEDRO GUILHERME DA SILVA
# 3        PEDRO FELIPE GOMES PEREIRA       PEDRO FELIPE GOMES PEREIRA
# 4               LUAN COSTA DA SILVA             LUANA COSTA DA SILVA
# ..                              ...                              ...
# 71        GUILHERME NASCIMENTO CRUZ        GUILHERME NASCIMENTO CRUZ
# 72           THALLYS GOMES FERREIRA            THALYS GOMES FERREIRA
# 73           MARIANA BEZERRA DA LUZ           MARIANA BEZERRA DA LUZ
# 74  MARIA EDUARDA SANTIAGO DA SILVA  MARIA EDUARDA SANTIAGO DA SILVA
# 75            GABRIEL CALEB CANDIDO            GABRIEL CALEB CANDIDO
#
#                                     curso instituicao situacao
# 0                               AGRONOMIA          SC        N
# ...

# %%
print(lista_espera_sisu21_1.columns)
# Out:
# Index(['"NU_ANO"', '"NU_EDICAO"', '"CO_ETAPA"', '"DS_ETAPA"', '"CO_IES"',
#        '"NO_IES"', '"SIGLA_IES"', '"SG_UF_IES"', '"CO_CAMPUS"', '"NO_CAMPUS"',
#        '"SG_UF_CAMPUS"', '"NO_MUNUCIPIO_CAMPUS"', '"CO_IES_CURSO"',
#        '"NO_CURSO"', '"DS_GRAU"', '"DS_TURNO"', '"TP_MOD_CONCORRENCIA"',
#        '"DS_MOD_CONCORRENCIA"', '"NU_PERCENTUAL_BONUS"', '"NU_PESO_L"',
#        '"NU_PESO_CH"', '"NU_PESO_CN"', '"NU_PESO_M"', '"NU_PESO_R"',
#        '"NOTA_MINIMA_L"', '"NOTA_MINIMA_CH"', '"NOTA_MINIMA_CN"',
#        '"NOTA_MINIMA_M"', '"NOTA_MINIMA_R"', '"MEDIA_MINIMA"', '"NU_CPF"',
#        '"CO_INSCRICAO_ENEM"', '"NO_INSCRITO"', '"TP_SEXO"', '"DT_NASCIMENTO"',
#        '"SG_UF_CANDIDATO"', '"MUNICIPIO_CANDIDATO"', '"ST_OPCAO"',
#        '"NU_NOTA_L"', '"NU_NOTA_CH"', '"NU_NOTA_CN"', '"NU_NOTA_M"',
#        '"NU_NOTA_R"', '"NOTA_L_COM_PESO"', '"NOTA_CH_COM_PESO"',
#        '"NOTA_CN_COM_PESO"', '"NOTA_M_COM_PESO"', '"NOTA_R_COM_PESO"',
# ...

# %%
display(lista_espera_sisu21_1['"SG_UF_CAMPUS"'])
# Out:
# 0         "SE"
# 1         "SE"
# 2         "SE"
# 3         "SE"
# 4         "SE"
#           ...
# 173086    "PI"
# 173087    "PE"
# 173088    "PI"
# 173089    "PI"
# 173090     NaN
# Name: "SG_UF_CAMPUS", Length: 173091, dtype: object

# %%
import pandas as pd
from rapidfuzz import process, fuzz

# Padroniza os nomes da lista CVT
nomes_cvt = nomes_cvt.str.upper().str.strip()

# Padroniza a coluna de nomes do DataFrame original
lista_espera_sisu21_1['nome_upper'] = nomes_lista_espera_sisu21_1.str.upper().str.strip()

resultados = []

for nome_aluno in nomes_cvt:
    resultado = process.extractOne(
        nome_aluno,
        lista_espera_sisu21_1['nome_upper'],
        scorer=fuzz.ratio
    )

    if resultado and resultado[1] >= 97:
        nome_correspondente = resultado[0]

        # Agora filtra usando a coluna já dentro do DataFrame com índice alinhado
        linha = lista_espera_sisu21_1[lista_espera_sisu21_1['nome_upper'] == nome_correspondente].iloc[0]

        resultados.append({
            'nome_original': nome_aluno,
            'nome_correspondente': nome_correspondente,
            'curso': linha['"NO_CURSO"'],
            'instituicao': linha['"SG_UF_CAMPUS"'],
            'situacao': linha['"ST_APROVADO"']
        })

df_resultados = pd.DataFrame(resultados)
df_resultados.to_csv('alunos_encontrados_LE_21_1.csv', index=False)
alunos_encontrados_LE_21_1 = pd.read_csv('alunos_encontrados_LE_21_1.csv')
display(alunos_encontrados_LE_21_1)
# Out:
#                        nome_original               nome_correspondente  \
# 0       ANA CAROLINA RODRIGUES COSTA      ANA CAROLINA RODRIGUES COSTA
# 1              MATEUS SOUSA DA SILVA            MATHEUS SOUSA DA SILVA
# 2             ALEX OLIVEIRA DA SILVA            ALEX OLIVEIRA DA SILVA
# 3         ANA CAROLINA ALVES DE LIMA        ANA CAROLINA ALVES DE LIMA
# 4   PEDRO HENRIQUE DE OLIVEIRA SILVA  PEDRO HENRIQUE DE OLIVEIRA SILVA
# 5     BEATRIZ FERREIRA DO NASCIMENTO    BEATRIZ FERREIRA DO NASCIMENTO
# 6            YURI RODRIGUES DA SILVA           YURI RODRIGUES DA SILVA
# 7          MARIA EDUARDA DE OLIVEIRA         MARIA EDUARDA DE OLIVEIRA
# 8     LUCAS RAFAEL FERREIRA DA SILVA    LUCAS RAFAEL FERREIRA DA SILVA
# 9    MARIA EDUARDA FERNANDES PEREIRA   MARIA EDUARDA FERNANDES PEREIRA
# 10              LUCAS FERREIRA SILVA              LUCAS FERREIRA SILVA
# 11           DANIEL BARBOSA DE SOUSA          DANIELA BARBOSA DE SOUSA
# ...

# %%
alunos_encontrados_LE_21_1['curso'] = alunos_encontrados_LE_21_1['curso'].str.strip('"')
alunos_encontrados_LE_21_1['situacao'] =  alunos_encontrados_LE_21_1['situacao'].str.strip('"')
alunos_encontrados_LE_21_1['instituicao'] =  alunos_encontrados_LE_21_1['instituicao'].str.strip('"')
display(alunos_encontrados_LE_21_1)
# Out:
#                        nome_original               nome_correspondente  \
# 0       ANA CAROLINA RODRIGUES COSTA      ANA CAROLINA RODRIGUES COSTA
# 1              MATEUS SOUSA DA SILVA            MATHEUS SOUSA DA SILVA
# 2             ALEX OLIVEIRA DA SILVA            ALEX OLIVEIRA DA SILVA
# 3         ANA CAROLINA ALVES DE LIMA        ANA CAROLINA ALVES DE LIMA
# 4   PEDRO HENRIQUE DE OLIVEIRA SILVA  PEDRO HENRIQUE DE OLIVEIRA SILVA
# 5     BEATRIZ FERREIRA DO NASCIMENTO    BEATRIZ FERREIRA DO NASCIMENTO
# 6            YURI RODRIGUES DA SILVA           YURI RODRIGUES DA SILVA
# 7          MARIA EDUARDA DE OLIVEIRA         MARIA EDUARDA DE OLIVEIRA
# 8     LUCAS RAFAEL FERREIRA DA SILVA    LUCAS RAFAEL FERREIRA DA SILVA
# 9    MARIA EDUARDA FERNANDES PEREIRA   MARIA EDUARDA FERNANDES PEREIRA
# 10              LUCAS FERREIRA SILVA              LUCAS FERREIRA SILVA
# 11           DANIEL BARBOSA DE SOUSA          DANIELA BARBOSA DE SOUSA
# ...

# %%
import pandas as pd
from rapidfuzz import process, fuzz

# Padroniza os nomes da lista CVT
nomes_cvt = nomes_cvt.str.upper().str.strip()

# Padroniza a coluna de nomes do DataFrame original
lista_espera_sisu21_2['nome_upper'] = nomes_lista_espera_sisu21_2.str.upper().str.strip()

resultados = []

for nome_aluno in nomes_cvt:
    resultado = process.extractOne(
        nome_aluno,
        lista_espera_sisu21_2['nome_upper'],
        scorer=fuzz.ratio
    )

    if resultado and resultado[1] >= 97:
        nome_correspondente = resultado[0]

        # Agora filtra usando a coluna já dentro do DataFrame com índice alinhado
        linha = lista_espera_sisu21_2[lista_espera_sisu21_2['nome_upper'] == nome_correspondente].iloc[0]

        resultados.append({
            'nome_original': nome_aluno,
            'nome_correspondente': nome_correspondente,
            'curso': linha['"NO_CURSO"'],
            'instituicao': linha['"UF_CAMPUS"'],
            'situacao': linha['"ST_APROVADO"']
        })

df_resultados = pd.DataFrame(resultados)
df_resultados.to_csv('alunos_encontrados_LE_21_2.csv', index=False)
alunos_encontrados_LE_21_2 = pd.read_csv('alunos_encontrados_LE_21_2.csv')
display(alunos_encontrados_LE_21_2)

# %%
# juntando todos os arquivos em um só

arquivos_anos = {
    'alunos_encontrados_sisu_21_1.csv': '2021',
    'alunos_encontrados_sisu_21_2.csv': '2021',
    'alunos_encontrados_sisu_22_1.csv': '2022',
    'alunos_encontrados_sisu_22_2.csv': '2022',
    'alunos_encontrados_sisu_23_1.csv': '2023',
    'alunos_encontrados_sisu_23_2.csv': '2023',
    'alunosuf22.csv': '2021',
    'alunosuf23.csv': '2022'
}

dfs = []

for arquivo, ano in arquivos_anos.items():
    df = pd.read_csv(arquivo)
    df['ano'] = ano
    df['nome_original'] = df['nome_original'].str.upper().str.strip()
    dfs.append(df)

# Junta todos os DataFrames em um só
df_unificado = pd.concat(dfs, ignore_index=True)

# Remove duplicatas com base no nome_original, mantendo o primeiro registro encontrado
df_unificado = df_unificado.drop_duplicates(subset='nome_original')

df_unificado.to_csv('alunos_unificados.csv', index=False)

# %%
import pandas as pd
alunos_unificados = pd.read_csv('alunos_unificados.csv')
display(alunos_unificados)

# %%
alunos_unificados['instituicao'] = alunos_unificados['instituicao'].fillna('RN')
display(alunos_unificados)

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

def is_rn(instituicao):
    return 'RN' in instituicao.upper()

# Criar nova coluna com categoria RN / Outros
alunos_unificados['local'] = alunos_unificados['instituicao'].apply(lambda x: 'RN' if is_rn(x) else 'Outros')

# Contar quantos alunos estão em RN e em Outros estados
contagem = alunos_unificados['local'].value_counts()

# Plotar gráfico de pizza
plt.figure(figsize=(6, 6))
plt.pie(contagem, labels=contagem.index, autopct='%1.1f%%', colors=['#4CAF50', '#FF5722'])
plt.title('Distribuição de Alunos por Local da Instituição')
plt.axis('equal')  # Deixa o gráfico circular
plt.show()

# %%
import matplotlib.pyplot as plt

# Calcular as porcentagens dos cursos
porcentagens_cursos = alunos_unificados['curso'].value_counts(normalize=True) * 100

# Separar cursos com mais de 1.5%
cursos_principais = porcentagens_cursos[porcentagens_cursos > 1.5]

# Somar os cursos com 1.5% ou menos
outros_percentual = porcentagens_cursos[porcentagens_cursos <= 1.5].sum()

if outros_percentual > 0:
    cursos_principais['Outros'] = outros_percentual

# Plotar gráfico de pizza
plt.figure(figsize=(8, 8))
plt.pie(cursos_principais, labels=cursos_principais.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribuição Percentual dos Cursos (agrupando <1.5% em "Outros")')
plt.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt


alunos_unificados['ano'] = alunos_unificados['ano'].astype(int)

def calcular_distribuicao_por_ano(df, ano, limite=2.5):
    df_ano = df[df['ano'] == ano]
    porcentagens = df_ano['curso'].value_counts(normalize=True) * 100
    cursos_principais = porcentagens[porcentagens > limite]
    outros = porcentagens[porcentagens <= limite].sum()
    if outros > 0:
        cursos_principais['Outros'] = outros
    return cursos_principais

distrib_2021 = calcular_distribuicao_por_ano(alunos_unificados, 2021)
distrib_2022 = calcular_distribuicao_por_ano(alunos_unificados, 2022)

# Criar subplots lado a lado
fig, axs = plt.subplots(1, 2, figsize=(14, 7))

# Gráfico de 2021
axs[0].pie(distrib_2021, labels=distrib_2021.index, autopct='%1.1f%%', startangle=140)
axs[0].set_title('Cursos - Ano 2021')
axs[0].axis('equal')

# Gráfico de 2022
axs[1].pie(distrib_2022, labels=distrib_2022.index, autopct='%1.1f%%', startangle=140)
axs[1].set_title('Cursos - Ano 2022')
axs[1].axis('equal')

# Mostrar os gráficos
plt.tight_layout()
plt.show()

# %%
def contar_cursos_com_outros(df, ano, limite_percentual=1.5):
    df_ano = df[df['ano'] == ano]
    total = len(df_ano)

    contagem = df_ano['curso'].value_counts()
    porcentagens = (contagem / total) * 100

    # Separar cursos acima do limite
    cursos_maiores = contagem[porcentagens > limite_percentual]

    # Agrupar os cursos menores como "Outros"
    outros = contagem[porcentagens <= limite_percentual].sum()

    if outros > 0:
        cursos_maiores['Outros'] = outros

    return cursos_maiores.astype(int)

contagem_2021 = contar_cursos_com_outros(alunos_unificados, 2021)
contagem_2022 = contar_cursos_com_outros(alunos_unificados, 2022)

print("Quantidade de alunos por curso 2021")
print(contagem_2021)

print("Quantidade de alunos por curso 2022")
print(contagem_2022)
